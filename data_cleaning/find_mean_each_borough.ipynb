# %%
import numpy as np
import pandas as pd
import json
import math
import plotly.express as px
from area import area

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# %%
df = pd.read_csv('neighborhood_prices_modified.csv').drop(columns=('Unnamed: 0'))

df
# Out:
#                                                ntaname boro_name  count  \
# 0                                         Borough Park  Brooklyn      1
# 1                                          Murray Hill    Queens      1
# 2                                        East Elmhurst    Queens      1
# 3                                              Erasmus  Brooklyn      2
# 4                                               Hollis    Queens      1
# ..                                                 ...       ...    ...
# 190                         park-cemetery-etc-Brooklyn  Brooklyn      0
# 191                                      Richmond Hill    Queens      1
# 192                                            Jamaica    Queens      1
# 193  Breezy Point-Belle Harbor-Rockaway Park-Broad ...    Queens      3
# 194                           park-cemetery-etc-Queens    Queens      0
#
#         2019-12-31     2020-01-31  2020-02-29     2020-03-31     2020-04-30  \
# ...

# %%
curr_boro = df.loc[(df['boro_name'] == 'Brooklyn') & (df['count'] > 0)]

# %%
curr_boro.loc['mean'] = df.mean()
# Out:
# C:\Users\Sena\.conda\envs\prog\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
curr_boro
# Out:
#                                                ntaname boro_name     count  \
# 0                                         Borough Park  Brooklyn  1.000000
# 3                                              Erasmus  Brooklyn  2.000000
# 5                                            Homecrest  Brooklyn  1.000000
# 8                                              Midwood  Brooklyn  1.000000
# 10                                        Clinton Hill  Brooklyn  1.000000
# 13                                       Starrett City  Brooklyn  1.000000
# 15                                             Madison  Brooklyn  3.000000
# 16                            Kensington-Ocean Parkway  Brooklyn  2.000000
# 17                                           Gravesend  Brooklyn  1.000000
# 18                                    Bensonhurst East  Brooklyn  1.000000
# 19                                        Williamsburg  Brooklyn  1.000000
# ...

# %%
curr_boro.iloc[-1, 0] = "Brooklyn"
curr_boro.iloc[-1, 1] = "Brooklyn"

curr_boro.reset_index()
# Out:
# C:\Users\Sena\.conda\envs\prog\lib\site-packages\pandas\core\indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#    index                                           ntaname boro_name  \
# 0      0                                      Borough Park  Brooklyn
# 1      3                                           Erasmus  Brooklyn
# 2      5                                         Homecrest  Brooklyn
# 3      8                                           Midwood  Brooklyn
# 4     10                                      Clinton Hill  Brooklyn
# 5     13                                     Starrett City  Brooklyn
# 6     15                                           Madison  Brooklyn
# ...
