# %%
import numpy as np
import pandas as pd
import json
import math
import plotly.express as px
from area import area

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# %%
df1 = pd.read_csv('neighborhood_locations_income.csv')

df2 = pd.read_csv('median_incomes_nyc_2019.csv')

df3 = pd.read_csv('neighborhood_prices_modified.csv')

# %%
df1
# Out:
#                                                ntaname boro_name  \
# 0                                         Borough Park  Brooklyn
# 1                                          Murray Hill    Queens
# 2                                        East Elmhurst    Queens
# 3                                              Erasmus  Brooklyn
# 4                                               Hollis    Queens
# ..                                                 ...       ...
# 190                         park-cemetery-etc-Brooklyn  Brooklyn
# 191                                      Richmond Hill    Queens
# 192                                            Jamaica    Queens
# 193  Breezy Point-Belle Harbor-Rockaway Park-Broad ...    Queens
# 194                           park-cemetery-etc-Queens    Queens
#
#             income_area
# 0          Borough Park
# 1              Flushing
# 2       Jackson Heights
# 3         East Flatbush
# 4    Jamaica/St. Albans
# ..                  ...
# 190                None
# 191           Woodhaven
# 192  Jamaica/St. Albans
# 193       The Rockaways
# 194                None
#
# [195 rows x 3 columns]

# %%
df2
# Out:
#                 Location  Household Type  TimeFrame DataFormat    Data  \
# 0          New York City  All Households       2019    Dollars   69407
# 1              Manhattan  All Households       2019    Dollars   93651
# 2   Battery Park/Tribeca  All Households       2019    Dollars  162092
# 3      Greenwich Village  All Households       2019    Dollars  162092
# 4        Lower East Side  All Households       2019    Dollars   41302
# ..                   ...             ...        ...        ...     ...
# 61         Staten Island  All Households       2019    Dollars   89821
# 62            St. George  All Households       2019    Dollars   75180
# 63           South Beach  All Households       2019    Dollars   82089
# 64           Tottenville  All Households       2019    Dollars  108025
# 65                  None  All Households       2019    Dollars       0
#
#        Fips
# 0   3651000
# 1     36061
# 2       101
# 3       102
# 4       103
# ..      ...
# 61    36085
# 62      501
# 63      502
# 64      503
# 65        0
#
# [66 rows x 6 columns]

# %%
for i in range(len(df1)):
    df1.loc[i, 'median_income'] = df2.loc[df2['Location'] == df1.loc[i, 'income_area'], 'Data'].values[0]

# %%
df1
# Out:
#                                                ntaname boro_name  \
# 0                                         Borough Park  Brooklyn
# 1                                          Murray Hill    Queens
# 2                                        East Elmhurst    Queens
# 3                                              Erasmus  Brooklyn
# 4                                               Hollis    Queens
# ..                                                 ...       ...
# 190                         park-cemetery-etc-Brooklyn  Brooklyn
# 191                                      Richmond Hill    Queens
# 192                                            Jamaica    Queens
# 193  Breezy Point-Belle Harbor-Rockaway Park-Broad ...    Queens
# 194                           park-cemetery-etc-Queens    Queens
#
#             income_area  median_income
# 0          Borough Park        55071.0
# 1              Flushing        54933.0
# 2       Jackson Heights        67201.0
# 3         East Flatbush        60895.0
# 4    Jamaica/St. Albans        65744.0
# ..                  ...            ...
# 190                None            0.0
# 191           Woodhaven        76978.0
# 192  Jamaica/St. Albans        65744.0
# 193       The Rockaways        55034.0
# 194                None            0.0
#
# [195 rows x 4 columns]

# %%
df3
# Out:
#      Unnamed: 0                                            ntaname boro_name  \
# 0             0                                       Borough Park  Brooklyn
# 1             1                                        Murray Hill    Queens
# 2             2                                      East Elmhurst    Queens
# 3             3                                            Erasmus  Brooklyn
# 4             4                                             Hollis    Queens
# ..          ...                                                ...       ...
# 190         190                         park-cemetery-etc-Brooklyn  Brooklyn
# 191         191                                      Richmond Hill    Queens
# 192         192                                            Jamaica    Queens
# 193         193  Breezy Point-Belle Harbor-Rockaway Park-Broad ...    Queens
# 194         194                           park-cemetery-etc-Queens    Queens
#
#      count     2019-12-31     2020-01-31  2020-02-29     2020-03-31  \
# 0        1  804830.000000  800107.000000    794346.0  792962.000000
# 1        1  385161.000000  384721.000000    384396.0  383443.000000
# 2        1  660059.000000  663453.000000    665648.0  667851.000000
# 3        2  583771.500000  581603.500000    578528.0  578563.500000
# 4        1  554610.000000  554907.000000    555797.0  556189.000000
# ..     ...            ...            ...         ...            ...
# 190      0       0.000000       0.000000         0.0       0.000000
# 191      1  572196.000000  571840.000000    572333.0  572168.000000
# 192      1  439218.000000  439332.000000    440256.0  441169.000000
# 193      3  531021.666667  531565.333333    533002.0  533948.666667
# 194      0       0.000000       0.000000         0.0       0.000000
#
#         2020-04-30     2020-05-31     2020-06-30     2020-07-31  2020-08-31  \
# 0    792549.000000  792589.000000  791801.000000  790573.000000    792553.0
# 1    383618.000000  383362.000000  383960.000000  384397.000000    384940.0
# 2    669964.000000  671708.000000  672445.000000  672120.000000    672802.0
# 3    580280.500000  584362.500000  586204.000000  589292.000000    592369.5
# 4    557034.000000  557172.000000  558160.000000  560169.000000    562641.0
# ..             ...            ...            ...            ...         ...
# 190       0.000000       0.000000       0.000000       0.000000         0.0
# 191  572098.000000  571145.000000  572393.000000  574503.000000    577717.0
# 192  442618.000000  443684.000000  445890.000000  448625.000000    451519.0
# 193  536517.666667  537704.666667  539185.333333  539979.666667    541870.0
# 194       0.000000       0.000000       0.000000       0.000000         0.0
#
#         2020-09-30  2020-10-31
# 0    794147.000000    792330.0
# 1    386321.000000    388206.0
# 2    676621.000000    681728.0
# 3    592750.500000    592178.0
# 4    566751.000000    568297.0
# ..             ...         ...
# 190       0.000000         0.0
# 191  581482.000000    583228.0
# 192  455501.000000    458605.0
# 193  544999.666667    548942.0
# 194       0.000000         0.0
#
# [195 rows x 15 columns]

# %%
df3['median_income'] = df1['median_income']

# %%
df3
# Out:
#      Unnamed: 0                                            ntaname boro_name  \
# 0             0                                       Borough Park  Brooklyn
# 1             1                                        Murray Hill    Queens
# 2             2                                      East Elmhurst    Queens
# 3             3                                            Erasmus  Brooklyn
# 4             4                                             Hollis    Queens
# ..          ...                                                ...       ...
# 190         190                         park-cemetery-etc-Brooklyn  Brooklyn
# 191         191                                      Richmond Hill    Queens
# 192         192                                            Jamaica    Queens
# 193         193  Breezy Point-Belle Harbor-Rockaway Park-Broad ...    Queens
# 194         194                           park-cemetery-etc-Queens    Queens
#
#      count     2019-12-31     2020-01-31  2020-02-29     2020-03-31  \
# 0        1  804830.000000  800107.000000    794346.0  792962.000000
# 1        1  385161.000000  384721.000000    384396.0  383443.000000
# 2        1  660059.000000  663453.000000    665648.0  667851.000000
# 3        2  583771.500000  581603.500000    578528.0  578563.500000
# 4        1  554610.000000  554907.000000    555797.0  556189.000000
# ..     ...            ...            ...         ...            ...
# 190      0       0.000000       0.000000         0.0       0.000000
# 191      1  572196.000000  571840.000000    572333.0  572168.000000
# 192      1  439218.000000  439332.000000    440256.0  441169.000000
# 193      3  531021.666667  531565.333333    533002.0  533948.666667
# 194      0       0.000000       0.000000         0.0       0.000000
#
#         2020-04-30     2020-05-31     2020-06-30     2020-07-31  2020-08-31  \
# 0    792549.000000  792589.000000  791801.000000  790573.000000    792553.0
# 1    383618.000000  383362.000000  383960.000000  384397.000000    384940.0
# 2    669964.000000  671708.000000  672445.000000  672120.000000    672802.0
# 3    580280.500000  584362.500000  586204.000000  589292.000000    592369.5
# 4    557034.000000  557172.000000  558160.000000  560169.000000    562641.0
# ..             ...            ...            ...            ...         ...
# 190       0.000000       0.000000       0.000000       0.000000         0.0
# 191  572098.000000  571145.000000  572393.000000  574503.000000    577717.0
# 192  442618.000000  443684.000000  445890.000000  448625.000000    451519.0
# 193  536517.666667  537704.666667  539185.333333  539979.666667    541870.0
# 194       0.000000       0.000000       0.000000       0.000000         0.0
#
#         2020-09-30  2020-10-31  median_income
# 0    794147.000000    792330.0        55071.0
# 1    386321.000000    388206.0        54933.0
# 2    676621.000000    681728.0        67201.0
# 3    592750.500000    592178.0        60895.0
# 4    566751.000000    568297.0        65744.0
# ..             ...         ...            ...
# 190       0.000000         0.0            0.0
# 191  581482.000000    583228.0        76978.0
# 192  455501.000000    458605.0        65744.0
# 193  544999.666667    548942.0        55034.0
# 194       0.000000         0.0            0.0
#
# [195 rows x 16 columns]

# %%
df = pd.read_csv('Neighborhood_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
df = df[df['City'] == 'New York']

nycmap = json.load(open("nyc_neighborhoods.geojson"))

dates = ('2019-12-31',
         '2020-01-31',
         '2020-02-29',
         '2020-03-31',
         '2020-04-30',
         '2020-05-31',
         '2020-06-30',
         '2020-07-31',
         '2020-08-31',
         '2020-09-30',
         '2020-10-31')

new_frame = pd.read_csv('neighborhood_prices_modified.csv')
income_loc = pd.read_csv('neighborhood_locations_income.csv')
income_df = pd.read_csv('median_incomes_nyc_2019.csv')

income_df.rename(columns={'Data': 'median_income'})
for i in range(len(income_loc)):
    income_loc.loc[i, 'median_income'] = \
    income_df.loc[income_df['Location'] == income_loc.loc[i, 'income_area'], 'Data'].values[0]


# add income to df
new_frame.insert(3, 'median_income', income_loc['median_income'])

# %%
new_frame
# Out:
#      Unnamed: 0                                            ntaname boro_name  \
# 0             0                                       Borough Park  Brooklyn
# 1             1                                        Murray Hill    Queens
# 2             2                                      East Elmhurst    Queens
# 3             3                                            Erasmus  Brooklyn
# 4             4                                             Hollis    Queens
# ..          ...                                                ...       ...
# 190         190                         park-cemetery-etc-Brooklyn  Brooklyn
# 191         191                                      Richmond Hill    Queens
# 192         192                                            Jamaica    Queens
# 193         193  Breezy Point-Belle Harbor-Rockaway Park-Broad ...    Queens
# 194         194                           park-cemetery-etc-Queens    Queens
#
#      median_income  count     2019-12-31     2020-01-31  2020-02-29  \
# 0          55071.0      1  804830.000000  800107.000000    794346.0
# 1          54933.0      1  385161.000000  384721.000000    384396.0
# 2          67201.0      1  660059.000000  663453.000000    665648.0
# 3          60895.0      2  583771.500000  581603.500000    578528.0
# 4          65744.0      1  554610.000000  554907.000000    555797.0
# ..             ...    ...            ...            ...         ...
# 190            0.0      0       0.000000       0.000000         0.0
# 191        76978.0      1  572196.000000  571840.000000    572333.0
# 192        65744.0      1  439218.000000  439332.000000    440256.0
# 193        55034.0      3  531021.666667  531565.333333    533002.0
# 194            0.0      0       0.000000       0.000000         0.0
#
#         2020-03-31     2020-04-30     2020-05-31     2020-06-30  \
# 0    792962.000000  792549.000000  792589.000000  791801.000000
# 1    383443.000000  383618.000000  383362.000000  383960.000000
# 2    667851.000000  669964.000000  671708.000000  672445.000000
# 3    578563.500000  580280.500000  584362.500000  586204.000000
# 4    556189.000000  557034.000000  557172.000000  558160.000000
# ..             ...            ...            ...            ...
# 190       0.000000       0.000000       0.000000       0.000000
# 191  572168.000000  572098.000000  571145.000000  572393.000000
# 192  441169.000000  442618.000000  443684.000000  445890.000000
# 193  533948.666667  536517.666667  537704.666667  539185.333333
# 194       0.000000       0.000000       0.000000       0.000000
#
#         2020-07-31  2020-08-31     2020-09-30  2020-10-31
# 0    790573.000000    792553.0  794147.000000    792330.0
# 1    384397.000000    384940.0  386321.000000    388206.0
# 2    672120.000000    672802.0  676621.000000    681728.0
# 3    589292.000000    592369.5  592750.500000    592178.0
# 4    560169.000000    562641.0  566751.000000    568297.0
# ..             ...         ...            ...         ...
# 190       0.000000         0.0       0.000000         0.0
# 191  574503.000000    577717.0  581482.000000    583228.0
# 192  448625.000000    451519.0  455501.000000    458605.0
# 193  539979.666667    541870.0  544999.666667    548942.0
# 194       0.000000         0.0       0.000000         0.0
#
# [195 rows x 16 columns]

# %%
income_df
# Out:
#                 Location  Household Type  TimeFrame DataFormat    Data  \
# 0          New York City  All Households       2019    Dollars   69407
# 1              Manhattan  All Households       2019    Dollars   93651
# 2   Battery Park/Tribeca  All Households       2019    Dollars  162092
# 3      Greenwich Village  All Households       2019    Dollars  162092
# 4        Lower East Side  All Households       2019    Dollars   41302
# ..                   ...             ...        ...        ...     ...
# 61         Staten Island  All Households       2019    Dollars   89821
# 62            St. George  All Households       2019    Dollars   75180
# 63           South Beach  All Households       2019    Dollars   82089
# 64           Tottenville  All Households       2019    Dollars  108025
# 65                  None  All Households       2019    Dollars       0
#
#        Fips
# 0   3651000
# 1     36061
# 2       101
# 3       102
# 4       103
# ..      ...
# 61    36085
# 62      501
# 63      502
# 64      503
# 65        0
#
# [66 rows x 6 columns]
